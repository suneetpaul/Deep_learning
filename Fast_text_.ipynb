# %% [markdown]
# <a href="https://colab.research.google.com/github/suneetpaul/Deep_learning/blob/main/Fast_text_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 43.3 MB/s eta 0:00:00
# ...

# %%
from gensim import models
from gensim.models import FastText

sentences = [
    ["i", "love" , "machine" , "learning"],
    ["machine" , "learning" , " is" , "powerful"],
    ["deep", "learning" , "is", "amazing"],
    ["i", "enjoy" , "deep", "learning"]

]

model = FastText(
    sentences,
    vector_size=50 , #siz of word vector
    window=3 ,    # context window size
    min_count=1,  # unclude all words
    epochs=100
)

# %%
vector = model.wv['learning']
print(vector)
# Out:
# [-1.0728213e-03 -2.0964382e-05  9.1411173e-05 -1.3240672e-03
#  -2.1893557e-03  1.0089428e-03  2.7145492e-03 -9.1906702e-05
#  -3.8848605e-03  1.2817554e-03  8.0925773e-04 -1.3198992e-03
#  -3.2127954e-04  2.3153634e-03  8.0818211e-04 -1.4093718e-03
#   1.8052974e-03 -7.4708834e-04 -9.5481606e-04  2.8957946e-03
#   1.9094123e-03 -6.0480076e-04 -2.7597686e-03  2.4467299e-03
#   2.2214164e-03 -2.5839796e-03 -2.5670482e-03  3.0499671e-03
#  -1.7177403e-03  4.6051918e-03  2.6711973e-03  2.7716234e-03
#  -1.7565696e-03  4.9778918e-04 -1.0380717e-03 -1.3896778e-03
#   7.0725969e-04  5.1360938e-04  4.0047802e-03  4.4760788e-03
#   2.2993593e-03  6.1868393e-04  2.7538086e-03 -5.6866262e-05
#  -1.5018696e-03 -1.0402439e-03 -4.3401779e-03 -3.4030005e-03
#  -2.1600972e-03  1.5672493e-03]

# %%
#oov (out - of - vocabulary)

model.wv["learner"]
# Out:
# array([-8.4893902e-05, -5.4507382e-04,  3.2124753e-04, -7.0566412e-06,
#         3.7958534e-03,  2.5290365e-03,  3.5694399e-04, -1.3803268e-03,
#        -6.1401040e-03,  1.8958253e-03, -1.5261709e-03, -5.4233515e-04,
#         3.0879749e-03,  4.7830815e-04,  8.7356294e-04, -2.7245405e-04,
#        -2.9433342e-03, -1.3045791e-03, -9.4683305e-04,  2.9330580e-03,
#        -4.7317357e-03,  5.6970032e-04, -7.9446810e-04,  3.6303899e-03,
#         1.8841415e-03, -4.3391632e-03, -4.9173331e-04,  9.1547292e-04,
#         4.8647111e-04, -2.5855040e-03,  3.0985712e-03, -1.2898787e-03,
#        -3.3306419e-03,  6.1393417e-05, -1.9679824e-03,  2.3498628e-03,
#         3.0826016e-03,  1.4167684e-03, -2.3640983e-03, -1.0584418e-03,
#         7.2663667e-04, -8.8653242e-04,  2.1772529e-03,  2.4103865e-03,
#        -5.4730807e-04,  6.5370766e-04, -4.1596154e-03, -2.9209256e-03,
#        -1.7431933e-03,  4.1936464e-03], dtype=float32)

# %%
similarit = model.wv.similarity("machine", "deep")

print(similarit)
# Out:
# -0.011575785
